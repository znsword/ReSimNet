# %% [markdown]
# # ReSimNet Colab Notebook
# 在 Google Colab 上运行 ReSimNet：依赖安装、数据准备、训练与预测示例

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvidia-smi || echo 'No GPU'
# !pip install -q numpy pandas scikit-learn seaborn plotly gdown
# Out:
# Wed Nov 26 21:50:27 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   46C    P8             12W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ## 准备工程与数据
# 请确保本仓库位于 "/content/ReSimNet"，并将必要数据放置到 "tasks/data" 目录。

# %%
import os, sys
ROOT = '/content/ReSimNet/ReSimNet'
if not os.path.exists(ROOT):
    print('请将仓库复制到 /content/ReSimNet/ReSimNet')
os.chdir(ROOT)
print('CWD:', os.getcwd())
# Out:
# 请将仓库复制到 /content/ReSimNet/ReSimNet
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1275559574.py in <cell line: 0>()
#       3 if not os.path.exists(ROOT):
#       4     print('请将仓库复制到 /content/ReSimNet/ReSimNet')
# ----> 5 os.chdir(ROOT)
#       6 print('CWD:', os.getcwd())
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/ReSimNet/ReSimNet'

# %% [markdown]
# ### 下载示例数据（可选）
# 根据 README 链接使用 gdown 下载到 tasks/data。

# %%
# 示例：下载主训练数据；请替换为有效的共享链接
# import gdown, os
# os.makedirs('tasks/data', exist_ok=True)
# gdown.download('<ReSimNet-Dataset.pkl 分享链接>', 'tasks/data/ReSimNet-Dataset.pkl', quiet=False)

# %% [markdown]
# ## 运行训练（ECFP，rep-idx=2）

# %%
# !python main.py --data-path './tasks/data/ReSimNet-Dataset.pkl' --model-name 'colab_model.mdl' --rep-idx 2 --train True --valid True --test True

# %% [markdown]
# ## 导出测试集预测

# %%
# !python main.py --save-prediction true --data-path './tasks/data/ReSimNet-Dataset.pkl' --model-name 'colab_model.mdl' --rep-idx 2

# %% [markdown]
# ## 对新药物对打分（需准备 pairs/ 与 pertid2fingerprint.pkl）

# %%
# !python main.py --save-pair-score true --pair-dir './tasks/data/pairs/' --fp-dir './tasks/data/pertid2fingerprint.pkl' --data-path './tasks/data/ReSimNet-Dataset.pkl' --model-name 'colab_model.mdl' --rep-idx 2
